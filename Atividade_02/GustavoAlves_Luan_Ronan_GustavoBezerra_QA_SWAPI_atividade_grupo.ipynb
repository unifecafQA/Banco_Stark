# %% [markdown]
# # Atividade Prática — QA com APIs (SWAPI)
#
# ## Versão do aluno — com scripts base
#
# **Tempo estimado:** 60 minutos
# **Ferramenta:** Google Colab
# **Formato:** em grupos de **2 a 4 componentes** ou, se preferirem, **individualmente**.
# **Objetivo:** investigar respostas de uma API, ajustar scripts simples e responder às perguntas como um QA.
#
# ### Instruções
# Nesta atividade, vocês **não precisam criar tudo do zero**.
# Os scripts já estão prontos como base. A tarefa do grupo será:
#
# 1. **Executar** os blocos de código
# 2. **Alterar apenas o que for pedido**
# 3. **Observar os resultados**
# 4. **Responder às perguntas em Markdown**
# 5. **Discutir em grupo** quais validações um QA faria
#
# ### Entrega
# Cada grupo pode entregar **um único notebook** com:
# - nomes dos integrantes
# - respostas das perguntas
# - scripts ajustados
# - asserts completados
#
# Se alguém optar por fazer sozinho, pode entregar individualmente sem problema.

# %%
import requests
import json

# -------------------------
# MODO DE SEGURANÇA (fallback)
# -------------------------
# Se a API não responder, o notebook usa dados locais
# para a atividade continuar funcionando.

DADOS_FALLBACK = {
    "https://swapi.dev/api/people/10/": {
        "name": "Obi-Wan Kenobi",
        "height": "182",
        "mass": "77",
        "eye_color": "blue-gray",
        "gender": "male",
        "url": "https://swapi.dev/api/people/10/"
    },
    "https://swapi.dev/api/people/13/": {
        "name": "Chewbacca",
        "height": "228",
        "mass": "112",
        "eye_color": "blue",
        "gender": "male",
        "url": "https://swapi.dev/api/people/13/"
    },
    "https://swapi.dev/api/planets/2/": {
        "name": "Alderaan",
        "climate": "temperate",
        "terrain": "grasslands, mountains",
        "population": "2000000000",
        "url": "https://swapi.dev/api/planets/2/"
    },
    "https://swapi.dev/api/starships/10/": {
        "name": "Millennium Falcon",
        "model": "YT-1300 light freighter",
        "manufacturer": "Corellian Engineering Corporation",
        "max_atmosphering_speed": "1050",
        "url": "https://swapi.dev/api/starships/10/"
    }
}

class RespostaLocal:
    def __init__(self, status_code, data):
        self.status_code = status_code
        self._data = data
        self.text = json.dumps(data, ensure_ascii=False)

    def json(self):
        return self._data

def buscar_endpoint(url):
    try:
        resposta = requests.get(url, timeout=10)
        if resposta.status_code == 200:
            return resposta, "online"
    except Exception:
        pass

    if url in DADOS_FALLBACK:
        return RespostaLocal(200, DADOS_FALLBACK[url]), "fallback local"

    return RespostaLocal(404, {"detail": "Not found"}), "fallback local"

print("Ambiente preparado com sucesso.")
# Out:
# Ambiente preparado com sucesso.

# %% [markdown]
# ## Identificação do grupo
#
# - Integrante 1:Gustavo Alves de Almeida
# - Integrante 2: Luan Hulne Soares de Oliveira
# - Integrante 3 (se houver):Gustavo Bezerra Silva
# - Integrante 4 (se houver):Ronan Oliveira Felicio
#
# ## Parte 1 — Explorando a API
#
# Nesta primeira parte, vocês vão consultar 4 endpoints.
# O trabalho do grupo será **alterar apenas a URL** em cada bloco, executar e observar o retorno.

# %% [markdown]
# ### 1.1 Personagem 20
#
# **Tarefa:** execute o script e observe:
# - status code
# - nome
# - altura
# - cor dos olhos

# %%
url = "https://swapi.dev/api/people/20/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Yoda",
#     "height": "66",
#     "mass": "17",
#     "hair_color": "white",
#     "skin_color": "green",
#     "eye_color": "brown",
#     "birth_year": "896BBY",
#     "gender": "male",
#     "homeworld": "https://swapi.dev/api/planets/28/",
#     "films": [
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/",
#         "https://swapi.dev/api/films/4/",
#         "https://swapi.dev/api/films/5/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "species": [
#         "https://swapi.dev/api/species/6/"
#     ],
#     "vehicles": [],
#     "starships": [],
#     "created": "2014-12-15T12:26:01.042000Z",
#     "edited": "2014-12-20T21:17:50.345000Z",
#     "url": "https://swapi.dev/api/people/20/"
# }

# %% [markdown]
# **Respostas do aluno — Personagem 20**
#
# - Status code: 200
# - Nome do personagem: Yoda
# - Altura: 66
# - Cor dos olhos: brown
# - O JSON parece completo? Sim, parece conter todas as informações relevantes para um personagem.

# %% [markdown]
# ### 1.2 Personagem 13
#
# **Tarefa:** neste bloco, troque apenas o endpoint se necessário, execute e observe o retorno.

# %%
url = "https://swapi.dev/api/people/13/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Chewbacca",
#     "height": "228",
#     "mass": "112",
#     "hair_color": "brown",
#     "skin_color": "unknown",
#     "eye_color": "blue",
#     "birth_year": "200BBY",
#     "gender": "male",
#     "homeworld": "https://swapi.dev/api/planets/14/",
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "species": [
#         "https://swapi.dev/api/species/3/"
#     ],
#     "vehicles": [
#         "https://swapi.dev/api/vehicles/19/"
#     ],
#     "starships": [
#         "https://swapi.dev/api/starships/10/",
#         "https://swapi.dev/api/starships/22/"
#     ],
#     "created": "2014-12-10T16:42:45.066000Z",
#     "edited": "2014-12-20T21:17:50.332000Z",
#     "url": "https://swapi.dev/api/people/13/"
# }

# %% [markdown]
# **Respostas do aluno — Personagem 13**
#
# - Status code: 200
# - Nome do personagem: Chewbacca
# - Altura: 228
# - Cor dos olhos: blue
# - O JSON parece completo? Sim, parece conter todas as informações relevantes para um personagem.

# %% [markdown]
# ### 1.3 Planeta 2
#
# **Tarefa:** execute o bloco e observe:
# - nome do planeta
# - clima
# - terreno
# - população

# %%
url = "https://swapi.dev/api/planets/2/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Alderaan",
#     "rotation_period": "24",
#     "orbital_period": "364",
#     "diameter": "12500",
#     "climate": "temperate",
#     "gravity": "1 standard",
#     "terrain": "grasslands, mountains",
#     "surface_water": "40",
#     "population": "2000000000",
#     "residents": [
#         "https://swapi.dev/api/people/5/",
#         "https://swapi.dev/api/people/68/",
#         "https://swapi.dev/api/people/81/"
#     ],
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "created": "2014-12-10T11:35:48.479000Z",
#     "edited": "2014-12-20T20:58:18.420000Z",
#     "url": "https://swapi.dev/api/planets/2/"
# }

# %% [markdown]
# **Respostas do aluno — Planeta 2**
#
# - Status code: 200
# - Nome do planeta: Alderaan
# - Clima: temperate
# - Terreno: grasslands, mountains
# - População: 2000000000
# - O JSON parece completo? Sim, parece conter todas as informações relevantes para um planeta.

# %% [markdown]
# ### 1.4 Nave 10
#
# **Tarefa:** execute o bloco e observe:
# - nome da nave
# - modelo
# - fabricante
# - velocidade máxima em atmosfera

# %%
url = "https://swapi.dev/api/starships/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Millennium Falcon",
#     "model": "YT-1300 light freighter",
#     "manufacturer": "Corellian Engineering Corporation",
#     "cost_in_credits": "100000",
#     "length": "34.37",
#     "max_atmosphering_speed": "1050",
#     "crew": "4",
#     "passengers": "6",
#     "cargo_capacity": "100000",
#     "consumables": "2 months",
#     "hyperdrive_rating": "0.5",
#     "MGLT": "75",
#     "starship_class": "Light freighter",
#     "pilots": [
#         "https://swapi.dev/api/people/13/",
#         "https://swapi.dev/api/people/14/",
#         "https://swapi.dev/api/people/25/",
#         "https://swapi.dev/api/people/31/"
#     ],
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/"
#     ],
#     "created": "2014-12-10T16:59:45.094000Z",
#     "edited": "2014-12-20T21:23:49.880000Z",
# ...

# %% [markdown]
# **Respostas do aluno — Nave 10**
#
# - Status code: 200
# - Nome da nave: Millennium Falcon
# - Modelo: YT-1300 light freighter
# - Fabricante: Corellian Engineering Corporation
# - Velocidade máxima em atmosfera: 1050
# - O JSON parece completo? Sim, parece conter todas as informações relevantes para uma nave.

# %% [markdown]
# ## Parte 2 — Extraindo campos específicos
#
# Agora você vai executar os scripts e **completar as respostas**.

# %% [markdown]
# ### 2.1 Extraindo campos do personagem
#
# **Tarefa:** execute o bloco e depois responda.

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Nome:", dados["name"])
print("Altura:", dados["height"])
print("Cor dos olhos:", dados["eye_color"])
print("Gênero:", dados["gender"])
# Out:
# Nome: Obi-Wan Kenobi
# Altura: 182
# Cor dos olhos: blue-gray
# Gênero: male

# %% [markdown]
# **Perguntas**
# 1. Qual campo foi usado para mostrar o nome? `name`
# 2. Qual campo foi usado para mostrar a altura? `height`
# 3. Se você fosse QA, quais desses campos validaria primeiro? O nome (`name`) e o gênero (`gender`), pois são campos essenciais para identificar o personagem. A altura e cor dos olhos são importantes, mas o nome e gênero são primários para a identificação.

# %% [markdown]
# ### 2.2 Extraindo campos do planeta
#
# **Tarefa:** execute o bloco e complete as respostas.

# %%
url = "https://swapi.dev/api/planets/2/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Nome do planeta:", dados["name"])
print("Clima:", dados["climate"])
print("Terreno:", dados["terrain"])
print("População:", dados["population"])
# Out:
# Nome do planeta: Alderaan
# Clima: temperate
# Terreno: grasslands, mountains
# População: 2000000000

# %% [markdown]
# **Perguntas**
# 1. O campo população parece numérico? Sim, `2000000000` é um valor numérico, embora retornado como string no JSON original.
# 2. O clima foi retornado corretamente? Sim, `temperate` está correto.
# 3. Se você fosse QA, o que validaria nesse planeta? Validaria se o campo `population` é realmente um número inteiro e se o campo `climate` e `terrain` contêm valores esperados ou uma lista de valores válidos.

# %% [markdown]
# ## Parte 3 — Pensando como QA
#
# Agora você vai trabalhar com validações simples.

# %% [markdown]
# ### 3.1 Validações básicas
#
# **Tarefa:** execute o bloco abaixo e depois escreva o que cada validação verifica.

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Validação 1 - status 200:", response.status_code == 200)
print("Validação 2 - campo 'name' existe:", "name" in dados)
print("Validação 3 - nome não está vazio:", dados["name"] != "")
print("Validação 4 - campo 'height' existe:", "height" in dados)
# Out:
# Validação 1 - status 200: True
# Validação 2 - campo 'name' existe: True
# Validação 3 - nome não está vazio: True
# Validação 4 - campo 'height' existe: True

# %% [markdown]
# **Explique com suas palavras**
# 1. O que a validação 1 verifica? Verifica se a requisição à API retornou com sucesso portanto o codigo 200 indica isso.
# 2. O que a validação 2 verifica? Verifica se o campo `name` está presente no JSON retornado.
# 3. O que a validação 3 verifica? Verifica se o valor do campo `name` não está vazio.
# 4. O que a validação 4 verifica? Verifica se o campo `height` está presente no JSON retornado.

# %% [markdown]
# ### 3.2 Complete as validações
#
# **Tarefa:** execute o bloco abaixo. Ele já está funcionando. Depois, alterem as expressões se o professor pedir outra nave ou outro endpoint. Em seguida, expliquem por que cada validação faz sentido para QA.

# %%
url = "https://swapi.dev/api/starships/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Status 200:", response.status_code == 200)

# Os exemplos abaixo já estão corretos e executáveis.
# Se o professor pedir, vocês podem alterar para validar outros campos.
print("Campo 'name' existe:", "name" in dados)
print("Campo 'model' existe:", "model" in dados)
print("Nome não está vazio:", dados["name"] != "")
# Out:
# Status 200: True
# Campo 'name' existe: True
# Campo 'model' existe: True
# Nome não está vazio: True

# %% [markdown]
# ## Parte 3.2 — Complete as validações
#
# - **Explique por que cada validação faz sentido para QA:**
#     *   **`print("Status 200:", response.status_code == 200)`**: É fundamental para um QA verificar se a requisição foi bem-sucedida (status 200 OK). se o status não for 200, significa que houve algum problema na comunicação ou no servidor.
#     *   **`print("Campo 'name' existe:", "name" in dados)`**: garante que o campo `name`, que geralmente é um identificador chave ou um dado esperado, está presente na resposta da API. pois sua ausencia poderia causar erros.
#     *   **`print("Campo 'model' existe:", "model" in dados)`**: Similar ao `name`, valida a presença de outro campo importante (`model`) para a entidade 'nave'.
#     *   **`print("Nome não está vazio:", dados["name"] != "")`**: Garante que o valor do campo `name` não é uma string vazia. Um nome vazio pode indicar dados incompletos ou problemas na base de dados, o que pode impactar a visibilidade.

# %% [markdown]
# ### 4.1 Assert no personagem
#
# **Tarefa:** execute o bloco. Depois, expliquem o que cada assert valida e, se quiserem, alterem o endpoint para outro personagem.

# %%
url = "https://swapi.dev/api/people/13/"
response, origem = buscar_endpoint(url)
dados = response.json()

assert response.status_code == 200, "Erro: status inesperado"
assert "name" in dados, "Erro: campo name não encontrado"
assert dados["name"] != "", "Erro: nome vazio"

print("Todos os testes do personagem passaram!")
# Out:
# Todos os testes do personagem passaram!

# %% [markdown]
# ### 4.1 Assert no personagem
#
# **Explicação dos asserts:**
# 1.  `assert response.status_code == 200, "Erro: status inesperado"`: Este assert verifica se o status da resposta HTTP é 200. Se não for, indica que houve um problema na requisição (por exemplo, recurso não encontrado, erro do servidor) e o teste falha, exibindo a mensagem "Erro: status inesperado".
# 2.  `assert "name" in dados, "Erro: campo name não encontrado"`: Este assert verifica se a chave "name" existe no dicionário `dados` (o JSON retornado). Se a chave não estiver presente, significa que o campo essencial de nome está faltando, e o teste falha com a mensagem "Erro: campo name não encontrado".
# 3.  `assert dados["name"] != "", "Erro: nome vazio"`: Este assert verifica se o valor associado à chave "name" no dicionário `dados` não é uma string vazia. Se o nome estiver vazio, pode indicar um problema de dados, e o teste falha com a mensagem "Erro: nome vazio".

# %%
url = "https://swapi.dev/api/starships/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

assert response.status_code == 200, "Erro: status inesperado"
assert "manufacturer" in dados, "Erro: fabricante não encontrado"
assert dados["model"] != "", "Erro: modelo vazio"

print("Todos os testes da nave passaram!")
# Out:
# Todos os testes da nave passaram!

# %% [markdown]
# ### 4.2 Assert na nave
#
# **Validação de cada assert:**
# 1.  `assert response.status_code == 200, "Erro: status inesperado"`: Valida o **status code** da resposta.
# 2.  `assert "manufacturer" in dados, "Erro: fabricante não encontrado"`: Valida a **existência do campo 'manufacturer'**.
# 3.  `assert dados["model"] != "", "Erro: modelo vazio"`: Valida que o **campo 'model' não está vazio**.
#
# **Proponha mais 1 validação extra em Markdown:**
# *   `assert int(dados["max_atmosphering_speed"]) > 0, "Erro: velocidade máxima atmosférica inválida"`: Valida se a velocidade máxima em atmosfera é um número inteiro e maior que zero, garantindo que o dado é numérico e faz sentido para uma nave.

# %%
url = "https://swapi.dev/api/people/9999/"
response, origem = buscar_endpoint(url)

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print("Texto retornado:")
print(response.text)
# Out:
# Origem dos dados: fallback local
# Status Code: 404
# Texto retornado:
# {"detail": "Not found"}

# %% [markdown]
# **Perguntas**
# 1. Qual status code foi retornado? O status code retornado foi **404**.
# 2. Esse comportamento está correto? Sim, esse comportamento está **correto**. O status 404 (Not Found) é a resposta padrão para quando um recurso solicitado não pode ser encontrado no servidor. É o que se espera ao tentar acessar um ID inexistente.
# 3. Por que um QA deve testar cenários negativos? Um QA deve testar cenários negativos para;
# Garantir a robustez do sistema: Verificar se a aplicação lida gracefully com situações inesperadas, como a ausência de dados, e não falha de forma abrupta.
# Validar o comportamento da API: Confirmar que a API retorna os códigos de status e mensagens de erro corretos, permitindo que os clientes (outras aplicações) interpretem o resultado da requisição e ajam de acordo.
# Melhorar a experiência do usuário: Cenários negativos bem tratados evitam que o usuário veja mensagens de erro genéricas ou confusas, oferecendo um feedback claro sobre o que aconteceu.

# %% [markdown]
# ## Parte 6 — Mini desafio final
#
# Agora você vai alterar apenas o endpoint da função abaixo e gerar um pequeno resumo.

# %%
def resumo_recurso(url):
    response, origem = buscar_endpoint(url)
    print("Origem dos dados:", origem)
    print("Status Code:", response.status_code)

    if response.status_code != 200:
        print("Recurso não encontrado.")
        return

    dados = response.json()

    for chave, valor in dados.items():
        print(f"{chave}: {valor}")

# ALTERE O ENDPOINT ABAIXO PARA TESTAR OUTRO RECURSO
resumo_recurso( "https://swapi.dev/api/people/10/")
# Out:
# Origem dos dados: online
# Status Code: 200
# name: Obi-Wan Kenobi
# height: 182
# mass: 77
# hair_color: auburn, white
# skin_color: fair
# eye_color: blue-gray
# birth_year: 57BBY
# gender: male
# homeworld: https://swapi.dev/api/planets/20/
# films: ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/', 'https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/']
# species: []
# vehicles: ['https://swapi.dev/api/vehicles/38/']
# starships: ['https://swapi.dev/api/starships/48/', 'https://swapi.dev/api/starships/59/', 'https://swapi.dev/api/starships/64/', 'https://swapi.dev/api/starships/65/', 'https://swapi.dev/api/starships/74/']
# created: 2014-12-10T16:16:29.192000Z
# edited: 2014-12-20T21:17:50.325000Z
# url: https://swapi.dev/api/people/10/

# %% [markdown]
#  **Respostas finais**
# 1. Qual endpoint você testou no desafio? Testei o endpoint  "https://swapi.dev/api/people/10/" (Obi-Wan Kenobi).
# 2. Qual foi o status code? O status code foi **200**.
# 3. Qual campo chamou mais a sua atenção? O campo `birth-year` (ano de nascimento) , por conta do padrao de datas de star wars.
# 4. Se você fosse QA, quais 3 validações faria nesse recurso?
#
#     *   **Validação 1: Status Code 200 (Sucesso):** Verificar se a requisição retornou com sucesso, indicando que o recurso foi encontrado e a API funcionou conforme o esperado.
#     *   **Validação 2: Existência dos Campos Essenciais:** Garantir que campos cruciais como `name`, `height`, `eye_color` e `gender` estão presentes na resposta, pois são dados fundamentais para a representação de um personagem.
#     *   **Validação 3: Validade dos Valores dos Campos:** Assegurar que o `name` não está vazio, que `height` e `mass` contêm valores numéricos válidos (mesmo que como string) e que `gender` está dentro de um conjunto de valores esperados (ex: "male", "female", "n/a", "none").

# %% [markdown]
# # Entrega da atividade
#
# Entreguem:
#
# 1. O notebook preenchido
# 2. As respostas em Markdown
# 3. Os scripts ajustados
# 4. Os asserts analisados e/ou adaptados
# 5. Uma conclusão curta do grupo: **quais foram as 3 validações mais importantes?**
#
# ## Fechamento
# Ao final desta atividade, vocês praticaram:
#
# - leitura de resposta JSON
# - análise de status code
# - validação de campos
# - pensamento de QA
# - testes simples com assert
# - análise de cenário negativo
#
# **Uma conclusão curta do grupo: quais foram as 3 validações mais importantes?**
# As 3 validações mais importantes para um QA seriam:
# 1.  **Status Code (200 OK para sucesso, 404 para não encontrado, etc.):** Garante a comunicação básica e a resposta esperada da API. Sem o status correto, qualquer outra validação pode ser irrelevante.
# 2.  **Existência de campos essenciais:** Confirma que os dados cruciais (como `name`, `id`, `model`) estão presentes na resposta, evitando erros de `KeyError` nas aplicações clientes.
# 3.  **Valores dos campos não-vazios e com formato esperado:** Assegura que os dados não estão em branco e seguem o tipo e formato esperados (ex: números são números, strings não estão vazias, URLs são válidas), garantindo a integridade e utilidade da informação.
