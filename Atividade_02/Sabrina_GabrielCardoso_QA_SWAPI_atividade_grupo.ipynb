# %% [markdown]
# # Atividade Prática — QA com APIs (SWAPI)
#
# ## Versão do aluno — com scripts base
#
# **Tempo estimado:** 60 minutos
# **Ferramenta:** Google Colab
# **Formato:** em grupos de **2 a 4 componentes** ou, se preferirem, **individualmente**.
# **Objetivo:** investigar respostas de uma API, ajustar scripts simples e responder às perguntas como um QA.
#
# ### Instruções
# Nesta atividade, vocês **não precisam criar tudo do zero**.
# Os scripts já estão prontos como base. A tarefa do grupo será:
#
# 1. **Executar** os blocos de código
# 2. **Alterar apenas o que for pedido**
# 3. **Observar os resultados**
# 4. **Responder às perguntas em Markdown**
# 5. **Discutir em grupo** quais validações um QA faria
#
# ### Entrega
# Cada grupo pode entregar **um único notebook** com:
# - nomes dos integrantes
# - respostas das perguntas
# - scripts ajustados
# - asserts completados
#
# Se alguém optar por fazer sozinho, pode entregar individualmente sem problema.

# %%
import requests
import json

# -------------------------
# MODO DE SEGURANÇA (fallback)
# -------------------------
# Se a API não responder, o notebook usa dados locais
# para a atividade continuar funcionando.

DADOS_FALLBACK = {
    "https://swapi.dev/api/people/10/": {
        "name": "Obi-Wan Kenobi",
        "height": "182",
        "mass": "77",
        "eye_color": "blue-gray",
        "gender": "male",
        "url": "https://swapi.dev/api/people/10/"
    },
    "https://swapi.dev/api/people/13/": {
        "name": "Chewbacca",
        "height": "228",
        "mass": "112",
        "eye_color": "blue",
        "gender": "male",
        "url": "https://swapi.dev/api/people/13/"
    },
    "https://swapi.dev/api/planets/2/": {
        "name": "Alderaan",
        "climate": "temperate",
        "terrain": "grasslands, mountains",
        "population": "2000000000",
        "url": "https://swapi.dev/api/planets/2/"
    },
    "https://swapi.dev/api/starships/10/": {
        "name": "Millennium Falcon",
        "model": "YT-1300 light freighter",
        "manufacturer": "Corellian Engineering Corporation",
        "max_atmosphering_speed": "1050",
        "url": "https://swapi.dev/api/starships/10/"
    }
}

class RespostaLocal:
    def __init__(self, status_code, data):
        self.status_code = status_code
        self._data = data
        self.text = json.dumps(data, ensure_ascii=False)

    def json(self):
        return self._data

def buscar_endpoint(url):
    try:
        resposta = requests.get(url, timeout=10)
        if resposta.status_code == 200:
            return resposta, "online"
    except Exception:
        pass

    if url in DADOS_FALLBACK:
        return RespostaLocal(200, DADOS_FALLBACK[url]), "fallback local"

    return RespostaLocal(404, {"detail": "Not found"}), "fallback local"

print("Ambiente preparado com sucesso.")
# Out:
# Ambiente preparado com sucesso.

# %% [markdown]
# ## Identificação do grupo
#
# - Integrante 1: Gabriel Pereira
# - Integrante 2: Sabrina Novais
# - Integrante 3 (se houver):
# - Integrante 4 (se houver):
#
# ## Parte 1 — Explorando a API
#
# Nesta primeira parte, vocês vão consultar 4 endpoints.
# O trabalho do grupo será **alterar apenas a URL** em cada bloco, executar e observar o retorno.

# %% [markdown]
# ### 1.1 Personagem 10
#
# **Tarefa:** execute o script e observe:
# - status code
# - nome
# - altura
# - cor dos olhos

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Obi-Wan Kenobi",
#     "height": "182",
#     "mass": "77",
#     "hair_color": "auburn, white",
#     "skin_color": "fair",
#     "eye_color": "blue-gray",
#     "birth_year": "57BBY",
#     "gender": "male",
#     "homeworld": "https://swapi.dev/api/planets/20/",
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/",
#         "https://swapi.dev/api/films/4/",
#         "https://swapi.dev/api/films/5/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "species": [],
#     "vehicles": [
#         "https://swapi.dev/api/vehicles/38/"
#     ],
#     "starships": [
#         "https://swapi.dev/api/starships/48/",
#         "https://swapi.dev/api/starships/59/",
#         "https://swapi.dev/api/starships/64/",
#         "https://swapi.dev/api/starships/65/",
#         "https://swapi.dev/api/starships/74/"
#     ],
#     "created": "2014-12-10T16:16:29.192000Z",
#     "edited": "2014-12-20T21:17:50.325000Z",
#     "url": "https://swapi.dev/api/people/10/"
# }

# %% [markdown]
# **Respostas do aluno — Personagem 10**
#
# - Status code: 200
# - Nome do personagem: Obi-Wan Kenobi
# - Altura: 182
# - Cor dos olhos: Blue
# - O JSON parece completo? R:
# Sim. O JSON retorna diversas informações do personagem, como nome, altura, peso, cor do cabelo, cor da pele, cor dos olhos, ano de nascimento, gênero, além de links para filmes, espécies, veículos e naves associadas ao personagem.

# %% [markdown]
# ### 1.2 Personagem 13
#
# **Tarefa:** neste bloco, troque apenas o endpoint se necessário, execute e observe o retorno.

# %%
url = "https://swapi.dev/api/people/13/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Chewbacca",
#     "height": "228",
#     "mass": "112",
#     "hair_color": "brown",
#     "skin_color": "unknown",
#     "eye_color": "blue",
#     "birth_year": "200BBY",
#     "gender": "male",
#     "homeworld": "https://swapi.dev/api/planets/14/",
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "species": [
#         "https://swapi.dev/api/species/3/"
#     ],
#     "vehicles": [
#         "https://swapi.dev/api/vehicles/19/"
#     ],
#     "starships": [
#         "https://swapi.dev/api/starships/10/",
#         "https://swapi.dev/api/starships/22/"
#     ],
#     "created": "2014-12-10T16:42:45.066000Z",
#     "edited": "2014-12-20T21:17:50.332000Z",
#     "url": "https://swapi.dev/api/people/13/"
# }

# %% [markdown]
# **Respostas do aluno — Personagem 13**
#
# - Status code: 200
# - Nome do personagem: Chewbacca
# - Altura: 228
# - Cor dos olhos: Blue
# - O JSON parece completo? Sim. O JSON traz várias informações além das solicitadas, como peso (mass), cor do cabelo (hair_color), cor da pele (skin_color), ano de nascimento (birth_year), gênero e links relacionados a filmes e naves.

# %% [markdown]
# ### 1.3 Planeta 2
#
# **Tarefa:** execute o bloco e observe:
# - nome do planeta
# - clima
# - terreno
# - população

# %%
url = "https://swapi.dev/api/planets/2/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Alderaan",
#     "rotation_period": "24",
#     "orbital_period": "364",
#     "diameter": "12500",
#     "climate": "temperate",
#     "gravity": "1 standard",
#     "terrain": "grasslands, mountains",
#     "surface_water": "40",
#     "population": "2000000000",
#     "residents": [
#         "https://swapi.dev/api/people/5/",
#         "https://swapi.dev/api/people/68/",
#         "https://swapi.dev/api/people/81/"
#     ],
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "created": "2014-12-10T11:35:48.479000Z",
#     "edited": "2014-12-20T20:58:18.420000Z",
#     "url": "https://swapi.dev/api/planets/2/"
# }

# %% [markdown]
# **Respostas do aluno — Planeta 2**
#
# - Status code: 200
# - Nome do planeta:Alderaan
# - Clima: Temperate
# - Terreno: Grasslands, Mountains
# - População: 2000000000
# - O JSON parece completo? Sim. O JSON contém várias informações do planeta, como diâmetro, gravidade, água na superfície, população, residentes e filmes relacionados, além da data de criação e edição.

# %% [markdown]
# ### 1.4 Nave 10
#
# **Tarefa:** execute o bloco e observe:
# - nome da nave
# - modelo
# - fabricante
# - velocidade máxima em atmosfera

# %%
url = "https://swapi.dev/api/starships/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Millennium Falcon",
#     "model": "YT-1300 light freighter",
#     "manufacturer": "Corellian Engineering Corporation",
#     "cost_in_credits": "100000",
#     "length": "34.37",
#     "max_atmosphering_speed": "1050",
#     "crew": "4",
#     "passengers": "6",
#     "cargo_capacity": "100000",
#     "consumables": "2 months",
#     "hyperdrive_rating": "0.5",
#     "MGLT": "75",
#     "starship_class": "Light freighter",
#     "pilots": [
#         "https://swapi.dev/api/people/13/",
#         "https://swapi.dev/api/people/14/",
#         "https://swapi.dev/api/people/25/",
#         "https://swapi.dev/api/people/31/"
#     ],
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/"
#     ],
#     "created": "2014-12-10T16:59:45.094000Z",
#     "edited": "2014-12-20T21:23:49.880000Z",
#     "url": "https://swapi.dev/api/starships/10/"
# }

# %% [markdown]
# **Respostas do aluno — Nave 10**
#
# - Status code: 200
# - Nome da nave: Millennium Falcon
# - Modelo: YT-1300 light freighter
# - Fabricante: Corellian Engineering Corporation
# - Velocidade máxima em atmosfera: 1050
# - O JSON parece completo? Sim. O JSON retorna várias informações adicionais além das solicitadas, como custo, tamanho, tripulação, passageiros, capacidade de carga, classe da nave, pilotos e filmes em que aparece.

# %% [markdown]
# ## Parte 2 — Extraindo campos específicos
#
# Agora você vai executar os scripts e **completar as respostas**.

# %% [markdown]
# ### 2.1 Extraindo campos do personagem
#
# **Tarefa:** execute o bloco e depois responda.

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Nome:", dados["name"])
print("Altura:", dados["height"])
print("Cor dos olhos:", dados["eye_color"])
print("Gênero:", dados["gender"])
# Out:
# Nome: Obi-Wan Kenobi
# Altura: 182
# Cor dos olhos: blue-gray
# Gênero: male

# %% [markdown]
# **Perguntas**
# 1. Qual campo foi usado para mostrar o nome? 'name'
# 2. Qual campo foi usado para mostrar a altura? 'height'
# 3. Se você fosse QA, quais desses campos validaria primeiro? Se eu estivesse atuando como QA, eu validaria primeiro o campo "name", porque ele confirma se o personagem retornado pela API está correto. Depois verificaria "height", "eye_color" e "gender" para garantir que as informações do personagem estão sendo retornadas corretamente e sem erros.

# %% [markdown]
# ### 2.2 Extraindo campos do planeta
#
# **Tarefa:** execute o bloco e complete as respostas.

# %%
url = "https://swapi.dev/api/planets/2/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Nome do planeta:", dados["name"])
print("Clima:", dados["climate"])
print("Terreno:", dados["terrain"])
print("População:", dados["population"])
# Out:
# Nome do planeta: Alderaan
# Clima: temperate
# Terreno: grasslands, mountains
# População: 2000000000

# %% [markdown]
# **Perguntas**
# 1. O campo população parece numérico? Sim, parece numérico porque aparece somente com números (2000000000). Porém, olhando melhor, ele vem como texto no JSON. Então, se fosse usar esse valor para cálculos em um sistema, talvez fosse necessário convertê-lo para número.
#
# 2. O clima foi retornado corretamente? Sim. O clima foi retornado como “temperate”, indicando que o planeta tem um clima temperado.
#
# 3. Se você fosse QA, o que validaria nesse planeta? Se eu estivesse atuando como QA, eu verificaria primeiro se as informações principais estão corretas, como nome do planeta, clima, terreno e população. Também conferiria se os dados estão preenchidos corretamente e se a API retornou status 200, garantindo que a requisição funcionou sem erros.

# %% [markdown]
# ## Parte 3 — Pensando como QA
#
# Agora você vai trabalhar com validações simples.

# %% [markdown]
# ### 3.1 Validações básicas
#
# **Tarefa:** execute o bloco abaixo e depois escreva o que cada validação verifica.

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Validação 1 - status 200:", response.status_code == 200)
print("Validação 2 - campo 'name' existe:", "name" in dados)
print("Validação 3 - nome não está vazio:", dados["name"] != "")
print("Validação 4 - campo 'height' existe:", "height" in dados)
# Out:
# Validação 1 - status 200: True
# Validação 2 - campo 'name' existe: True
# Validação 3 - nome não está vazio: True
# Validação 4 - campo 'height' existe: True

# %% [markdown]
# **Explique com suas palavras**
# 1. O que a validação 1 verifica?
# A validação 1 verifica se a requisição para a API retornou status 200, ou seja, se a resposta foi bem-sucedida e os dados foram encontrados.
#
# 2. O que a validação 2 verifica?
# A validação 2 verifica se o campo "name" existe dentro dos dados retornados pela API.
#
# 3. O que a validação 3 verifica?
# A validação 3 verifica se o campo "name" não está vazio, garantindo que o nome do personagem foi realmente retornado.
#
# 4. O que a validação 4 verifica?
# A validação 4 verifica se o campo "height" existe nos dados retornados, confirmando que a informação de altura está presente na resposta da API.

# %% [markdown]
# ### 3.2 Complete as validações
#
# **Tarefa:** execute o bloco abaixo. Ele já está funcionando. Depois, alterem as expressões se o professor pedir outra nave ou outro endpoint. Em seguida, expliquem por que cada validação faz sentido para QA.

# %% [markdown]
# Status 200:
# Essa validação verifica se a requisição foi feita com sucesso. Quando o status é 200, significa que a API respondeu corretamente e o recurso foi encontrado.
#
# Campo "name" existe:
# Aqui verificamos se o campo "name" está presente nos dados retornados. Isso é importante porque o nome da nave é uma informação principal.
#
# Campo "model" existe:
# Essa validação garante que o campo "model" também está presente no retorno da API, mostrando qual é o modelo da nave.
#
# Nome não está vazio:
# Essa verificação confirma que o campo "name" não está vazio. Assim garantimos que a API não está retornando um campo sem valor.
#
# Essas validações fazem sentido para QA porque ajudam a garantir que a API está respondendo corretamente e que as informações principais da nave estão presentes e preenchidas. No caso desse endpoint da Star Wars API, os dados retornados são da nave Millennium Falcon.

# %%
url = "https://swapi.dev/api/starships/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Status 200:", response.status_code == 200)

# Os exemplos abaixo já estão corretos e executáveis.
# Se o professor pedir, vocês podem alterar para validar outros campos.
print("Campo 'name' existe:", "name" in dados)
print("Campo 'model' existe:", "model" in dados)
print("Nome não está vazio:", dados["name"] != "")
# Out:
# Status 200: True
# Campo 'name' existe: True
# Campo 'model' existe: True
# Nome não está vazio: True

# %% [markdown]
# ## Parte 4 — Testes automatizados com assert
#
# Agora vocês vão trabalhar sobre scripts já prontos. Os asserts abaixo já executam sem erro. A tarefa do grupo é **entender o que cada linha valida**, ajustar se o professor pedir outro recurso e registrar as respostas.

# %% [markdown]
# ### 4.1 Assert no personagem
#
# **Tarefa:** execute o bloco. Depois, expliquem o que cada assert valida e, se quiserem, alterem o endpoint para outro personagem.

# %% [markdown]
# 1- assert response.status_code == 200
# Esse teste verifica se a requisição para a API foi realizada com sucesso. Quando o status é 200, significa que o personagem foi encontrado e os dados foram retornados corretamente.
#
# 2️- Segundo assert
# assert "name" in dados
# Esse teste verifica se o campo "name" existe dentro dos dados retornados pela API. Isso garante que a informação do nome do personagem está presente.
#
# 3- Terceiro assert
# assert dados["name"] != ""
# Esse teste verifica se o campo "name" não está vazio. Ou seja, além de existir, ele precisa ter um valor preenchido.

# %%
url = "https://swapi.dev/api/people/13/"
response, origem = buscar_endpoint(url)
dados = response.json()

assert response.status_code == 200, "Erro: status inesperado"
assert "name" in dados, "Erro: campo name não encontrado"
assert dados["name"] != "", "Erro: nome vazio"

print("Todos os testes do personagem passaram!")
# Out:
# Todos os testes do personagem passaram!

# %% [markdown]
# ### 4.2 Assert na nave
#
# **Tarefa:** execute o bloco. Depois, descrevam qual campo foi validado em cada assert e proponham mais 1 validação extra em Markdown.

# %%
url = "https://swapi.dev/api/starships/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

assert response.status_code == 200, "Erro: status inesperado"
assert "manufacturer" in dados, "Erro: fabricante não encontrado"
assert dados["model"] != "", "Erro: modelo vazio"
assert "name" in dados, "Erro: nome da nave não encontrado"

print("Todos os testes da nave passaram!")
# Out:
# Todos os testes da nave passaram!

# %% [markdown]
# ## Parte 5 — Cenário negativo
#
# Agora você vai observar como a API se comporta quando pedimos um recurso inexistente.

# %%
url = "https://swapi.dev/api/people/9999/"
response, origem = buscar_endpoint(url)

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print("Texto retornado:")
print(response.text)
# Out:
# Origem dos dados: fallback local
# Status Code: 404
# Texto retornado:
# {"detail": "Not found"}

# %% [markdown]
# **Perguntas**
# 1. Qual status code foi retornado? 404
# 2. Esse comportamento está correto? Sim, está correto. Como estamos tentando acessar um personagem que não existe (people/9999), é esperado que a API retorne 404, indicando que aquele recurso não foi encontrado na Star Wars API.
# 3. Por que um QA deve testar cenários negativos? Um QA precisa testar cenários negativos para garantir que o sistema também se comporta corretamente quando algo dá errado, como quando um usuário solicita um dado que não existe. Isso ajuda a verificar se a API retorna erros adequados e se o sistema consegue lidar com essas situações sem quebrar ou apresentar informações incorretas.

# %% [markdown]
# ## Parte 6 — Mini desafio final
#
# Agora você vai alterar apenas o endpoint da função abaixo e gerar um pequeno resumo.

# %%
def resumo_recurso(url):
    response, origem = buscar_endpoint(url)
    print("Origem dos dados:", origem)
    print("Status Code:", response.status_code)

    if response.status_code != 200:
        print("Recurso não encontrado.")
        return

    dados = response.json()

    for chave, valor in dados.items():
        print(f"{chave}: {valor}")

# ALTERE O ENDPOINT ABAIXO PARA TESTAR OUTRO RECURSO
resumo_recurso("https://swapi.dev/api/starships/10/")
# Out:
# Origem dos dados: online
# Status Code: 200
# name: Millennium Falcon
# model: YT-1300 light freighter
# manufacturer: Corellian Engineering Corporation
# cost_in_credits: 100000
# length: 34.37
# max_atmosphering_speed: 1050
# crew: 4
# passengers: 6
# cargo_capacity: 100000
# consumables: 2 months
# hyperdrive_rating: 0.5
# MGLT: 75
# starship_class: Light freighter
# pilots: ['https://swapi.dev/api/people/13/', 'https://swapi.dev/api/people/14/', 'https://swapi.dev/api/people/25/', 'https://swapi.dev/api/people/31/']
# films: ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/']
# created: 2014-12-10T16:59:45.094000Z
# edited: 2014-12-20T21:23:49.880000Z
# url: https://swapi.dev/api/starships/10/

# %% [markdown]
# **Respostas finais**
# 1. Qual endpoint você testou no desafio?
# Eu testei o endpoint https://swapi.dev/api/starships/10/
# que retorna informações sobre a nave Millennium Falcon.
#
# 2. Qual foi o status code?
# 200
#
# 3. Qual campo chamou mais a sua atenção?
# O campo max_atmosphering_speed, porque mostra a velocidade máxima da nave dentro da atmosfera.
#
# 4. Se você fosse QA, quais 3 validações faria nesse recurso?
#
# Se eu estivesse atuando como QA, eu validaria:
# Se o status code da resposta é 200.
# Se o campo name existe e está preenchido corretamente.
# Se o campo model existe e contém a informação do modelo da nave.

# %% [markdown]
# # Entrega da atividade
#
# Entreguem:
#
# 1. O notebook preenchido
# 2. As respostas em Markdown
# 3. Os scripts ajustados
# 4. Os asserts analisados e/ou adaptados
# 5. Uma conclusão curta do grupo: **quais foram as 3 validações mais importantes?**
#
# ## Fechamento
# Ao final desta atividade, vocês praticaram:
#
# - leitura de resposta JSON
# - análise de status code
# - validação de campos
# - pensamento de QA
# - testes simples com assert
# - análise de cenário negativo

# %% [markdown]
# quais foram as 3 validações mais importantes?
#
# As três validações mais importantes foram verificar se a requisição foi realizada com sucesso (status 200), confirmar se os campos principais existem no retorno da API, e garantir que esses campos não estão vazios. Essas validações são essenciais para garantir que os dados retornados pela Star Wars API estão corretos e completos.
