# %% [markdown]
# # Atividade Prática — QA com APIs (SWAPI)
#
# ## Versão do aluno — com scripts base
#
# **Tempo estimado:** 60 minutos
# **Ferramenta:** Google Colab
# **Formato:** em grupos de **2 a 4 componentes** ou, se preferirem, **individualmente**.
# **Objetivo:** investigar respostas de uma API, ajustar scripts simples e responder às perguntas como um QA.
#
# ### Instruções
# Nesta atividade, vocês **não precisam criar tudo do zero**.
# Os scripts já estão prontos como base. A tarefa do grupo será:
#
# 1. **Executar** os blocos de código
# 2. **Alterar apenas o que for pedido**
# 3. **Observar os resultados**
# 4. **Responder às perguntas em Markdown**
# 5. **Discutir em grupo** quais validações um QA faria
#
# ### Entrega
# Cada grupo pode entregar **um único notebook** com:
# - nomes dos integrantes:
# - respostas das perguntas
# - scripts ajustados
# - asserts completados
#
# Se alguém optar por fazer sozinho, pode entregar individualmente sem problema.

# %%
import requests
import json

# -------------------------
# MODO DE SEGURANÇA (fallback)
# -------------------------
# Se a API não responder, o notebook usa dados locais
# para a atividade continuar funcionando.

DADOS_FALLBACK = {
    "https://swapi.dev/api/people/10/": {
        "name": "Obi-Wan Kenobi",
        "height": "182",
        "mass": "77",
        "eye_color": "blue-gray",
        "gender": "male",
        "url": "https://swapi.dev/api/people/10/"
    },
    "https://swapi.dev/api/people/13/": {
        "name": "Chewbacca",
        "height": "228",
        "mass": "112",
        "eye_color": "blue",
        "gender": "male",
        "url": "https://swapi.dev/api/people/13/"
    },
    "https://swapi.dev/api/planets/2/": {
        "name": "Alderaan",
        "climate": "temperate",
        "terrain": "grasslands, mountains",
        "population": "2000000000",
        "url": "https://swapi.dev/api/planets/2/"
    },
    "https://swapi.dev/api/starships/10/": {
        "name": "Millennium Falcon",
        "model": "YT-1300 light freighter",
        "manufacturer": "Corellian Engineering Corporation",
        "max_atmosphering_speed": "1050",
        "url": "https://swapi.dev/api/starships/10/"
    }
}

class RespostaLocal:
    def __init__(self, status_code, data):
        self.status_code = status_code
        self._data = data
        self.text = json.dumps(data, ensure_ascii=False)

    def json(self):
        return self._data

def buscar_endpoint(url):
    try:
        resposta = requests.get(url, timeout=10)
        if resposta.status_code == 200:
            return resposta, "online"
    except Exception:
        pass

    if url in DADOS_FALLBACK:
        return RespostaLocal(200, DADOS_FALLBACK[url]), "fallback local"

    return RespostaLocal(404, {"detail": "Not found"}), "fallback local"

print("Ambiente preparado com sucesso.")
# Out:
# Ambiente preparado com sucesso.

# %% [markdown]
# ## Identificação do grupo
#
# - Integrante 1: Andressa Jorge Moreira
# - Integrante 2: Guilherme Freitas Marques da Silva
# - Integrante 3: Gustavo da Silva Pedroso
# - Integrante 4: Ryan Oliveira Amaral
#
# ## Parte 1 — Explorando a API
#
# Nesta primeira parte, vocês vão consultar 4 endpoints.
# O trabalho do grupo será **alterar apenas a URL** em cada bloco, executar e observar o retorno.

# %% [markdown]
# ### 1.1 Personagem 8
#
# **Tarefa:** execute o script e observe:
# - status code
# - nome
# - altura
# - cor dos olhos

# %%
url = "https://swapi.dev/api/people/8/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "R5-D4",
#     "height": "97",
#     "mass": "32",
#     "hair_color": "n/a",
#     "skin_color": "white, red",
#     "eye_color": "red",
#     "birth_year": "unknown",
#     "gender": "n/a",
#     "homeworld": "https://swapi.dev/api/planets/1/",
#     "films": [
#         "https://swapi.dev/api/films/1/"
#     ],
#     "species": [
#         "https://swapi.dev/api/species/2/"
#     ],
#     "vehicles": [],
#     "starships": [],
#     "created": "2014-12-10T15:57:50.959000Z",
#     "edited": "2014-12-20T21:17:50.321000Z",
#     "url": "https://swapi.dev/api/people/8/"
# }

# %% [markdown]
# **Respostas do aluno — Personagem 8**
#
# - Status code: 200
# - Nome do personagem: R5-D4
# - Altura: 97
# - Cor dos olhos: red
# - O JSON parece completo? Sim

# %% [markdown]
# ### 1.2 Personagem 12
#
# **Tarefa:** neste bloco, troque apenas o endpoint se necessário, execute e observe o retorno.

# %%
url = "https://swapi.dev/api/people/12/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Wilhuff Tarkin",
#     "height": "180",
#     "mass": "unknown",
#     "hair_color": "auburn, grey",
#     "skin_color": "fair",
#     "eye_color": "blue",
#     "birth_year": "64BBY",
#     "gender": "male",
#     "homeworld": "https://swapi.dev/api/planets/21/",
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "species": [],
#     "vehicles": [],
#     "starships": [],
#     "created": "2014-12-10T16:26:56.138000Z",
#     "edited": "2014-12-20T21:17:50.330000Z",
#     "url": "https://swapi.dev/api/people/12/"
# }

# %% [markdown]
# **Respostas do aluno — Personagem 12**
#
# - Status code: 200
# - Nome do personagem: Wilhuff Tarkin
# - Altura: 180
# - Cor dos olhos: blue
# - O JSON parece completo? Sim

# %% [markdown]
# ### 1.3 Planeta 6
#
# **Tarefa:** execute o bloco e observe:
# - nome do planeta
# - clima
# - terreno
# - população

# %%
url = "https://swapi.dev/api/planets/6/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "Bespin",
#     "rotation_period": "12",
#     "orbital_period": "5110",
#     "diameter": "118000",
#     "climate": "temperate",
#     "gravity": "1.5 (surface), 1 standard (Cloud City)",
#     "terrain": "gas giant",
#     "surface_water": "0",
#     "population": "6000000",
#     "residents": [
#         "https://swapi.dev/api/people/26/"
#     ],
#     "films": [
#         "https://swapi.dev/api/films/2/"
#     ],
#     "created": "2014-12-10T11:43:55.240000Z",
#     "edited": "2014-12-20T20:58:18.427000Z",
#     "url": "https://swapi.dev/api/planets/6/"
# }

# %% [markdown]
# **Respostas do aluno — Planeta 6**
#
# - Status code: 200
# - Nome do planeta: Bespin
# - Clima: temperate
# - Terreno: gas giant
# - População: 6000000
# - O JSON parece completo? Sim

# %% [markdown]
# ### 1.4 Nave 13
#
# **Tarefa:** execute o bloco e observe:
# - nome da nave
# - modelo
# - fabricante
# - velocidade máxima em atmosfera

# %%
url = "https://swapi.dev/api/starships/13/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print(json.dumps(dados, indent=4, ensure_ascii=False))
# Out:
# Origem dos dados: online
# Status Code: 200
# {
#     "name": "TIE Advanced x1",
#     "model": "Twin Ion Engine Advanced x1",
#     "manufacturer": "Sienar Fleet Systems",
#     "cost_in_credits": "unknown",
#     "length": "9.2",
#     "max_atmosphering_speed": "1200",
#     "crew": "1",
#     "passengers": "0",
#     "cargo_capacity": "150",
#     "consumables": "5 days",
#     "hyperdrive_rating": "1.0",
#     "MGLT": "105",
#     "starship_class": "Starfighter",
#     "pilots": [
#         "https://swapi.dev/api/people/4/"
#     ],
#     "films": [
#         "https://swapi.dev/api/films/1/"
#     ],
#     "created": "2014-12-12T11:21:32.991000Z",
#     "edited": "2014-12-20T21:23:49.889000Z",
#     "url": "https://swapi.dev/api/starships/13/"
# }

# %% [markdown]
# **Respostas do aluno — Nave 13**
#
# - Status code: 200
# - Nome da nave: TIE Advanced x1
# - Modelo: Twin Ion Engine Advanced x1
# - Fabricante: Sienar Fleet Systems
# - Velocidade máxima em atmosfera: 1200
# - O JSON parece completo? Sim

# %% [markdown]
# ## Parte 2 — Extraindo campos específicos
#
# Agora você vai executar os scripts e **completar as respostas**.

# %% [markdown]
# ### 2.1 Extraindo campos do personagem
#
# **Tarefa:** execute o bloco e depois responda.

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Nome:", dados["name"])
print("Altura:", dados["height"])
print("Cor dos olhos:", dados["eye_color"])
print("Gênero:", dados["gender"])
# Out:
# Nome: Obi-Wan Kenobi
# Altura: 182
# Cor dos olhos: blue-gray
# Gênero: male

# %% [markdown]
# **Perguntas**
# 1. Qual campo foi usado para mostrar o nome? name
# 2. Qual campo foi usado para mostrar a altura? height
# 3. Se você fosse QA, quais desses campos validaria primeiro?
#      Primeiro o campo name, pois é o identificador principal. Depois o campo height, para garantir que o valor numérico está correto.

# %% [markdown]
# ### 2.2 Extraindo campos do planeta
#
# **Tarefa:** execute o bloco e complete as respostas.

# %%
url = "https://swapi.dev/api/planets/7/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Nome do planeta:", dados["name"])
print("Clima:", dados["climate"])
print("Terreno:", dados["terrain"])
print("População:", dados["population"])
# Out:
# Nome do planeta: Endor
# Clima: temperate
# Terreno: forests, mountains, lakes
# População: 30000000

# %% [markdown]
# **Perguntas**
# 1. O campo população parece numérico? Sim, 30000000
# 2. O clima foi retornado corretamente? Sim
# 3. Se você fosse QA, o que validaria nesse planeta?
# Eu validaria se os campos name, climate, terrain e population estão sendo retornados corretamente

# %% [markdown]
# ## Parte 3 — Pensando como QA
#
# Agora você vai trabalhar com validações simples.

# %% [markdown]
# ### 3.1 Validações básicas
#
# **Tarefa:** execute o bloco abaixo e depois escreva o que cada validação verifica.

# %%
url = "https://swapi.dev/api/people/15/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Validação 1 - status 200:", response.status_code == 200)
print("Validação 2 - campo 'name' existe:", "name" in dados)
print("Validação 3 - nome não está vazio:", dados["name"] != "")
print("Validação 4 - campo 'height' existe:", "height" in dados)
# Out:
# Validação 1 - status 200: True
# Validação 2 - campo 'name' existe: True
# Validação 3 - nome não está vazio: True
# Validação 4 - campo 'height' existe: True

# %% [markdown]
# **Explique com suas palavras**
# 1. O que a validação 1 verifica? Verifica se o status code é verdadeiro
# 2. O que a validação 2 verifica? Verifica se o campo name existe
# 3. O que a validação 3 verifica? Verifica se o campo name está vazio
# 4. O que a validação 4 verifica? Verifica se o campo height existe

# %% [markdown]
# ### 3.2 Complete as validações
#
# **Tarefa:** execute o bloco abaixo. Ele já está funcionando. Depois, alterem as expressões se o professor pedir outra nave ou outro endpoint. Em seguida, expliquem por que cada validação faz sentido para QA.

# %%
url = "https://swapi.dev/api/starships/15/"
response, origem = buscar_endpoint(url)
dados = response.json()

print("Status 200:", response.status_code == 200)

# Os exemplos abaixo já estão corretos e executáveis.
# Se o professor pedir, vocês podem alterar para validar outros campos.
print("Campo 'name' existe:", "name" in dados)
print("Campo 'model' existe:", "model" in dados)
print("Nome não está vazio:", dados["name"] != "")
# Out:
# Status 200: True
# Campo 'name' existe: True
# Campo 'model' existe: True
# Nome não está vazio: True

# %% [markdown]
# **Explique com suas palavras**
#
# Status 200:
# Verifica se a requisição para a API foi bem-sucedida.
#
# Campo name existe:
# Confirma que o campo name está presente no JSON.
#
# Campo model existe:
# Confirma que o campo model foi retornado pela API.
#
# Nome não está vazio:
# Garante que o campo name possui um valor e não está em branco.

# %% [markdown]
# ## Parte 4 — Testes automatizados com assert
#
# Agora vocês vão trabalhar sobre scripts já prontos. Os asserts abaixo já executam sem erro. A tarefa do grupo é **entender o que cada linha valida**, ajustar se o professor pedir outro recurso e registrar as respostas.

# %% [markdown]
# ### 4.1 Assert no personagem
#
# **Tarefa:** execute o bloco. Depois, expliquem o que cada assert valida e, se quiserem, alterem o endpoint para outro personagem.

# %%
url = "https://swapi.dev/api/people/10/"
response, origem = buscar_endpoint(url)
dados = response.json()

assert response.status_code == 200, "Erro: status inesperado"
assert "name" in dados, "Erro: campo name não encontrado"
assert dados["name"] != "", "Erro: nome vazio"

print("Todos os testes do personagem passaram!")
# Out:
# Todos os testes do personagem passaram!

# %% [markdown]
# **Explique com suas palavras**
#
# assert response.status_code == 200 :
# Verifica se a requisição para a API foi bem-sucedida. Se o status não for 200, o teste falha.
#
# assert "name" in dados:
# Confirma que o campo name existe no JSON retornado pela API.
#
# assert dados["name"] != "":
# Verifica se o campo name não está vazio, garantindo que o personagem possui um nome.

# %% [markdown]
# ### 4.2 Assert na nave
#
# **Tarefa:** execute o bloco. Depois, descrevam qual campo foi validado em cada assert e proponham mais 1 validação extra em Markdown.

# %%
url = "https://swapi.dev/api/starships/5/"
response, origem = buscar_endpoint(url)
dados = response.json()

assert response.status_code == 200, "Erro: status inesperado"
assert "manufacturer" in dados, "Erro: fabricante não encontrado"
assert dados["model"] != "", "Erro: modelo vazio"

print("Todos os testes da nave passaram!")
# Out:
# Todos os testes da nave passaram!

# %% [markdown]
# **Explique com suas palavras**
#
# assert response.status_code == 200:
# Valida se a requisição para a API foi bem-sucedida (status 200).
#
# assert "manufacturer" in dados:
# Valida se o campo manufacturer existe no JSON retornado pela API.
#
# assert dados["model"] != "":
# Valida se o campo model não está vazio.
#
# **Validação Extra**:
# assert "name" in dados, "Erro: nome da nave não encontrado"
#
# Essa validação garantiria que o campo name da nave também está presente nos dados retornados pela API Star Wars API.

# %% [markdown]
# ## Parte 5 — Cenário negativo
#
# Agora você vai observar como a API se comporta quando pedimos um recurso inexistente.

# %%
url = "https://swapi.dev/api/people/9999/"
response, origem = buscar_endpoint(url)

print("Origem dos dados:", origem)
print("Status Code:", response.status_code)
print("Texto retornado:")
print(response.text)
# Out:
# Origem dos dados: fallback local
# Status Code: 404
# Texto retornado:
# {"detail": "Not found"}

# %% [markdown]
# **Perguntas**
# 1. Qual status code foi retornado? 404
# 2. Esse comportamento está correto? Sim
# 3. Por que um QA deve testar cenários negativos?
# Um QA testa cenários negativos para ver como o sistema reage a dados inválidos ou erros.

# %% [markdown]
# ## Parte 6 — Mini desafio final
#
# Agora você vai alterar apenas o endpoint da função abaixo e gerar um pequeno resumo.

# %%
def resumo_recurso(url):
    response, origem = buscar_endpoint(url)
    print("Origem dos dados:", origem)
    print("Status Code:", response.status_code)

    if response.status_code != 200:
        print("Recurso não encontrado.")
        return

    dados = response.json()

    for chave, valor in dados.items():
        print(f"{chave}: {valor}")

# ALTERE O ENDPOINT ABAIXO PARA TESTAR OUTRO RECURSO
resumo_recurso("https://swapi.dev/api/planets/15/")
# Out:
# Origem dos dados: online
# Status Code: 200
# name: Polis Massa
# rotation_period: 24
# orbital_period: 590
# diameter: 0
# climate: artificial temperate
# gravity: 0.56 standard
# terrain: airless asteroid
# surface_water: 0
# population: 1000000
# residents: []
# films: ['https://swapi.dev/api/films/6/']
# created: 2014-12-10T13:33:46.405000Z
# edited: 2014-12-20T20:58:18.444000Z
# url: https://swapi.dev/api/planets/15/

# %% [markdown]
# **Respostas finais**
# 1. Qual endpoint você testou no desafio? 15
# 2. Qual foi o status code? 200
# 3. Qual campo chamou mais a sua atenção? terrain: airless asteroid
# 4. Se você fosse QA, quais 3 validações faria nesse recurso?
#  1.Verificar se o status code é 200, garantindo que a API retornou os dados corretamente.
# 2.Validar se o campo name está presente e contém um valor (ex.: Polis Massa).
# 3.Verificar se o campo population existe e contém um número coerente para o planeta Polis Massa.

# %% [markdown]
# Uma conclusão curta do grupo: **quais foram as 3 validações mais importantes?**
#
#
#
# 1.   Verificar o status code 200 – garantir que a requisição para a API Star Wars API foi bem-sucedida.
#
# 2.   Confirmar se os campos existem – validar se campos importantes (como name, model, height) estão presentes no JSON.
#
# 3.   Garantir que os campos não estão vazios – verificar se os dados retornados possuem valores válidos.

# %% [markdown]
# # Entrega da atividade
#
# Entreguem:
#
# 1. O notebook preenchido
# 2. As respostas em Markdown
# 3. Os scripts ajustados
# 4. Os asserts analisados e/ou adaptados
# 5. Uma conclusão curta do grupo: **quais foram as 3 validações mais importantes?**
#
#
# ## Fechamento
# Ao final desta atividade, vocês praticaram:
#
# - leitura de resposta JSON
# - análise de status code
# - validação de campos
# - pensamento de QA
# - testes simples com assert
# - análise de cenário negativo
