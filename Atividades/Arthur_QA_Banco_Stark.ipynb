# %% [markdown]
# Criando a CLASSE conta

# %%
class Conta:
    def __init__(self, titular):
        self.titular = titular
        self.saldo = 0
        self.extrato = []

print('Classe Conta criada')
# Out:
# Classe Conta criada

# %% [markdown]
# Criando o Banco

# %%
class BancoDoStark:
    def __init__(self):
        self.contas = {}

    def criar_conta(self, titular):
        if titular in self.contas:
            print('Conta já existe')
            return

        self.contas[titular] = Conta(titular)
        print('Conta criada para', titular)

print('Classe Banco criada')
# Out:
# Classe Banco criada

# %% [markdown]
# Criando as operações Bancárias

# %%
class BancoDoStark:
    def __init__(self):
        self.contas = {}

    def criar_conta(self, titular):
        if titular in self.contas:
            print('Conta já existe')
            return
        self.contas[titular] = Conta(titular)
        print('Conta criada para', titular)

    def depositar(self, titular, valor):
        if titular not in self.contas:
            print('Conta não encontrada')
            return

        self.contas[titular].saldo += valor
        self.contas[titular].extrato.append(('deposito',valor))

        print('Depósito realizado:',valor)

    def sacar(self, titular, valor):
        if titular not in self.contas:
            print('Conta não encontrada')
            return

        if self.contas[titular].saldo < valor:
            print('Saldo insuficiente')
            return

        self.contas[titular].saldo -= valor
        self.contas[titular].extrato.append(('saque',valor))

        print('Saque realizado:',valor)

    def saldo(self, titular):
        if titular not in self.contas:
            print('Conta não encontrada')
            return

        print('Saldo de', titular, '=', self.contas[titular].saldo)

print('Operações adicionadas')
# Out:
# Operações adicionadas

# %%
banco = BancoDoStark()
print('Banco Stark em Funcionamento')
# Out:
# Banco Stark em Funcionamento

# %% [markdown]
# Caminho Feliz

# %%
banco.criar_conta('James')
banco.criar_conta('Tony')
banco.criar_conta('Steve')
banco.criar_conta('Bruce')
# Out:
# Conta já existe
# Conta criada para Tony
# Conta criada para Steve
# Conta criada para Bruce

# %%
banco.depositar('James', 5000)
banco.depositar('Tony', 8000)
banco.depositar('Steve', 10000)
banco.depositar('Bruce', 15000)
# Out:
# Depósito realizado: 5000
# Depósito realizado: 8000
# Depósito realizado: 10000
# Depósito realizado: 15000

# %%
banco.sacar('James', 1000)
banco.sacar('Tony', 1000)
banco.sacar('Steve', 1000)
banco.sacar('Bruce', 1000)
# Out:
# Saque realizado: 1000
# Saque realizado: 1000
# Saque realizado: 1000
# Saque realizado: 1000

# %%
banco.saldo('James')
banco.saldo('Tony')
banco.saldo('Steve')
banco.saldo('Bruce')
# Out:
# Saldo de James = 6200
# Saldo de Tony = 7000
# Saldo de Steve = 9000
# Saldo de Bruce = 14000

# %% [markdown]
# QA - Testes Negativos

# %%
banco.criar_conta('123')
# Out:
# Conta criada para 123

# %%
banco.depositar('123', -1000)
banco.depositar('James', -50000)
# Out:
# Depósito realizado: -1000
# Depósito realizado: -50000

# %%
banco.depositar('Bruce', 0)
# Out:
# Depósito realizado: 0

# %%
banco.depositar('Steve', 9999999999999999999999999999999999999999999999999999999999999999999)
# Out:
# Depósito realizado: 9999999999999999999999999999999999999999999999999999999999999999999

# %%
banco.sacar('Bruce', dez mil doláres)
# Out:
#   File "/tmp/ipykernel_1046/1874758772.py", line 1
#     banco.sacar('Bruce', dez mil doláres)
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# Transferências????

# %%
def transferir(self, origem: str, destino: str, valor: float):
        if origem not in self.contas:
            print('ERRO - Conta origem não encontrada')
            return
        if destino not in self.contas:
            print('ERRO - Conta destino não encontrada')
            return
        if self.contas[origem].saldo < valor:
            print('ERRO - Saldo insuficiente')
            return
        self.contas[origem].saldo -= valor
        self.contas[destino].saldo += valor
        self.contas[origem].extrato.append(('transferencia_saida', valor))
        self.contas[destino].extrato.append(('transferencia_entrada', valor))
        print('OK - Transferência realizada:', valor)

# %%
transferir(banco, 'James', 'Bruce', 4500)
# Out:
# OK - Transferência realizada: 4500

# %%
banco.saldo('James')
# Out:
# Saldo de James = 46200

# %%
banco.depositar('James', 45000)
# Out:
# Depósito realizado: 45000
